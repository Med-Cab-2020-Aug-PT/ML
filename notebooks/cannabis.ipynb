# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data_sources/cannabis.csv")

# %%
df.head(20)
# Out:
#                     Strain    Type  Rating  \
# 0                   100-Og  hybrid     4.0
# 1           98-White-Widow  hybrid     4.7
# 2                     1024  sativa     4.4
# 3                 13-Dawgs  hybrid     4.2
# 4                 24K-Gold  hybrid     4.6
# 5               3-Bears-Og  indica     0.0
# 6                  3-Kings  hybrid     4.4
# 7                   303-Og  indica     4.2
# 8                   3D-Cbd  sativa     4.6
# 9                 3X-Crazy  indica     4.4
# 10  3Rd-Coast-Panama-Chunk  hybrid     4.7
# 11                501St-Og  hybrid     4.5
# 12             5Th-Element  indica     4.4
# 13            707-Headband  hybrid     4.3
# 14             8-Ball-Kush  indica     4.3
# 15                  818-Og  indica     4.7
# 16                  831-Og  indica     5.0
# 17          9-Pound-Hammer  indica     4.5
# 18                91-Krypt  indica     4.7
# 19                    A-10  indica     3.8
#
# ...

# %%
df['Rating'] = df['Rating'].apply(lambda s: np.NaN if s == 0.0 else s)

# %%
df['Effects'] = df['Effects'].apply(lambda s: np.NaN if s == "None" else s)

# %%
df['Flavor'] = df['Flavor'].apply(lambda s: np.NaN if s == "None" else s)

# %%
df = df.dropna()
df.head(10)
# Out:
#                     Strain    Type  Rating  \
# 0                   100-Og  hybrid     4.0
# 1           98-White-Widow  hybrid     4.7
# 2                     1024  sativa     4.4
# 3                 13-Dawgs  hybrid     4.2
# 4                 24K-Gold  hybrid     4.6
# 6                  3-Kings  hybrid     4.4
# 7                   303-Og  indica     4.2
# 8                   3D-Cbd  sativa     4.6
# 9                 3X-Crazy  indica     4.4
# 10  3Rd-Coast-Panama-Chunk  hybrid     4.7
#
#                                        Effects                     Flavor  \
# 0   Creative,Energetic,Tingly,Euphoric,Relaxed        Earthy,Sweet,Citrus
# 1     Relaxed,Aroused,Creative,Happy,Energetic      Flowery,Violet,Diesel
# 2    Uplifted,Happy,Relaxed,Energetic,Creative    Spicy/Herbal,Sage,Woody
# 3      Tingly,Creative,Hungry,Relaxed,Uplifted  Apricot,Citrus,Grapefruit
# 4    Happy,Relaxed,Euphoric,Uplifted,Talkative       Citrus,Earthy,Orange
# ...

# %%
df.isna().sum()
# Out:
# Strain         0
# Type           0
# Rating         0
# Effects        0
# Flavor         0
# Description    0
# dtype: int64

# %%
for column_name in ('Effects', 'Flavor'):
    df[column_name] = df[column_name].str.split(',')

# %%
df.head(30)
# Out:
#                     Strain    Type  Rating  \
# 0                   100-Og  hybrid     4.0
# 1           98-White-Widow  hybrid     4.7
# 2                     1024  sativa     4.4
# 3                 13-Dawgs  hybrid     4.2
# 4                 24K-Gold  hybrid     4.6
# 6                  3-Kings  hybrid     4.4
# 7                   303-Og  indica     4.2
# 8                   3D-Cbd  sativa     4.6
# 9                 3X-Crazy  indica     4.4
# 10  3Rd-Coast-Panama-Chunk  hybrid     4.7
# 11                501St-Og  hybrid     4.5
# 12             5Th-Element  indica     4.4
# 13            707-Headband  hybrid     4.3
# 14             8-Ball-Kush  indica     4.3
# 15                  818-Og  indica     4.7
# 17          9-Pound-Hammer  indica     4.5
# 18                91-Krypt  indica     4.7
# 19                    A-10  indica     3.8
# 20                   A-Dub  hybrid     4.4
# 21                 A-Train  hybrid     4.1
# 22                    Acdc  hybrid     4.5
# ...

# %%
raw_score = SentimentIntensityAnalyzer()

def sentiment_score(sentence: str) -> int:
    sentiment_dict = raw_score.polarity_scores(sentence)
    return (100 + sentiment_dict['compound'] * 101) // 2

# %%
# df['Sentiment'] = df['Description'].apply(sentiment_score).astype(int)

# %%
# print(f"Sentiment Score Range: {df['Sentiment'].min()} - {df['Sentiment'].max()}")

# %%
# df = df.sort_values(by=['Rating', 'Sentiment'], ascending=False)
# df = df.reset_index().drop(columns=['index'])
# df.head(10)

# %%
df[df['Strain'].isin([
    'Sour-Diesel', 
    'Wedding-Cake', 
    'God-Bud',
])].sort_values(by='Rating', ascending=False)
# Out:
#             Strain    Type  Rating                                    Effects  \
# 2255  Wedding-Cake  hybrid     4.7    Relaxed,Happy,Euphoric,Uplifted,Focused
# 1933   Sour-Diesel  sativa     4.4  Happy,Uplifted,Euphoric,Energetic,Relaxed
# 871        God-Bud  indica     4.3     Relaxed,Happy,Euphoric,Uplifted,Sleepy
#
#                      Flavor                                        Description
# 2255   Sweet,Vanilla,Earthy  Wedding Cake, also known as Pink Cookies, is t...
# 1933  Diesel,Pungent,Earthy  Sour Diesel, sometimes called Sour D, is an in...
# 871    Pungent,Earthy,Sweet  God Bud, originally from Jordan of the Islands...

# %%
# Train/Validation Split

# %%
# Model Choice

# %%
# Make Predictions

# %%
# Flask App

# %%
# Deploy on Heroku

# %%
# Iterate and Add Features

# %%
# Pay Down Any Technical Debt
